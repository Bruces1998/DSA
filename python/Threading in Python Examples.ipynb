# %%
import logging
import threading
import time

def thread_function(name):
    logging.info('Threading %s: starting', name)
    time.sleep(2)
    logging.info('Threading %s: finishing', name)
    
if __name__ == "__main__":
    formatt = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO, 
                        datefmt="%H:%M:%S")
    
    logging.info("Main  :before creating thread")
    x = threading.Thread(target=thread_function, args = (1,))
    x.start()
    logging.info("Main   :wait for all the thread to finish")
    logging.info("Main   :all done")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 620, in format
#     if self.usesTime():
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 588, in usesTime
#     return self._style.usesTime()
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 430, in usesTime
#     return self._fmt.find(self.asctime_search) >= 0
# AttributeError: 'builtin_function_or_method' object has no attribute 'find'
# Call stack:
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2854, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2880, in _run_cell
#     return runner(coro)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3057, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b341373a285d>", line 15, in <module>
#     logging.info("Main  :before creating thread")
# Message: 'Main  :before creating thread'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 620, in format
#     if self.usesTime():
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 588, in usesTime
#     return self._style.usesTime()
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 430, in usesTime
#     return self._fmt.find(self.asctime_search) >= 0
# AttributeError: 'builtin_function_or_method' object has no attribute 'find'
# Call stack:
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-b341373a285d>", line 6, in thread_function
#     logging.info('Threading %s: starting', name)
# Message: 'Threading %s: starting'
# Arguments: (1,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 620, in format
#     if self.usesTime():
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 588, in usesTime
#     return self._style.usesTime()
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 430, in usesTime
#     return self._fmt.find(self.asctime_search) >= 0
# AttributeError: 'builtin_function_or_method' object has no attribute 'find'
# Call stack:
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2854, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2880, in _run_cell
#     return runner(coro)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3057, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b341373a285d>", line 18, in <module>
#     logging.info("Main   :wait for all the thread to finish")
# Message: 'Main   :wait for all the thread to finish'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 620, in format
#     if self.usesTime():
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 588, in usesTime
#     return self._style.usesTime()
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 430, in usesTime
#     return self._fmt.find(self.asctime_search) >= 0
# AttributeError: 'builtin_function_or_method' object has no attribute 'find'
# Call stack:
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/aniket/anaconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/home/aniket/anaconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2854, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2880, in _run_cell
#     return runner(coro)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3057, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3248, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/aniket/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b341373a285d>", line 19, in <module>
#     logging.info("Main   :all done")
# Message: 'Main   :all done'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 620, in format
#     if self.usesTime():
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 588, in usesTime
#     return self._style.usesTime()
#   File "/home/aniket/anaconda3/lib/python3.7/logging/__init__.py", line 430, in usesTime
#     return self._fmt.find(self.asctime_search) >= 0
# AttributeError: 'builtin_function_or_method' object has no attribute 'find'
# Call stack:
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/aniket/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-b341373a285d>", line 8, in thread_function
#     logging.info('Threading %s: finishing', name)
# Message: 'Threading %s: finishing'
# Arguments: (1,)
